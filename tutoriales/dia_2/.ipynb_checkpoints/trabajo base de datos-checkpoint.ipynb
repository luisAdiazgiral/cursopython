# %%
import numpy as np
import pandas as pd

# %%
curso_file='data/3medio.csv'

# %%
alumnos=pd.read_csv(curso_file, header=0, sep=',')

# %%
print('Tabla de estudiantes: ', alumnos.columns.values.tolist())
# Out:
# Tabla de estudiantes:  ['First Name', 'Last Name', 'Email', 'Student ID', 'Last Login', 'Grade', 'Complete (Y/N)']

# %%
alumnos.head()
# Out:
#   First Name   Last Name                               Email  Student ID  \
# 0      Marco  Altamirano  marco.ignacio.altamirano@gmail.com         NaN
# 1      diego     aravena         diego.aravenacpjk@gmail.com         NaN
# 2      Bryan       Araya                allelbryan@gmail.com         NaN
# 3    Nicolas     Cabrera    nicolascabreramillacan@gmail.com         NaN
# 4    denisse      cayupe            denisse.cayupe@yahoo.com         NaN
#
#                      Last Login  Grade  Complete (Y/N)
# 0  Wed Sep 27 15:03:46 GMT 2017  47.60           False
# 1  Wed Sep 27 14:49:52 GMT 2017  50.13           False
# 2  Wed Aug 09 12:57:12 GMT 2017    NaN           False
# 3  Tue Sep 26 22:13:38 GMT 2017  52.03           False
# 4  Wed Sep 27 00:40:07 GMT 2017  54.37           False

# %%
alumnos.loc[3].Email
# Out:
# 'nicolascabreramillacan@gmail.com'

# %%
alumnos.loc[3,'Last Name']='perez' #para cambiar un dato de la base desde un registro especifico

# %%
alumnos
# Out:
#    First Name    Last Name                                 Email  Student ID  \
# 0       Marco   Altamirano    marco.ignacio.altamirano@gmail.com         NaN
# 1       diego      aravena           diego.aravenacpjk@gmail.com         NaN
# 2       Bryan        Araya                  allelbryan@gmail.com         NaN
# 3     Nicolas        perez      nicolascabreramillacan@gmail.com         NaN
# 4     denisse       cayupe              denisse.cayupe@yahoo.com         NaN
# 5   christian     Gonzalez            christianalvaroo@gmail.com         NaN
# 6   Sebastian    Henriquez  sebaandres.henriquezsoarzo@gmail.com         NaN
# 7     ignacio    hernandez                 ignacioh809@gmail.com         NaN
# 8     nicolas      ignacio                      nuv741@gmail.com         NaN
# 9     Bastian         Jara                bastianjara3@yahoo.com         NaN
# 10      Denis        Julio                denisjulio62@gmail.com         NaN
# ...
